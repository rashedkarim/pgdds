# %%
import numpy as np
rand_num = np.random.rand(100)
rand_num
# Out:
# array([0.63723699, 0.62709873, 0.61327206, 0.16271616, 0.12144001,
#        0.69311704, 0.09510536, 0.82038307, 0.48430765, 0.44778463,
#        0.07422827, 0.02946464, 0.20282296, 0.15927391, 0.14876023,
#        0.32482618, 0.18457464, 0.06710517, 0.23411191, 0.80460043,
#        0.61145205, 0.67448148, 0.33709141, 0.33239125, 0.68078214,
#        0.53521398, 0.45700063, 0.7396814 , 0.93464335, 0.64197404,
#        0.94183419, 0.71052169, 0.27368394, 0.37275497, 0.56889121,
#        0.38088058, 0.71583035, 0.22156131, 0.12170903, 0.67440687,
#        0.55770241, 0.90407869, 0.78857997, 0.14828748, 0.22805376,
#        0.97756869, 0.78392329, 0.15552782, 0.74901565, 0.726409  ,
#        0.80646525, 0.08084039, 0.32135005, 0.27356663, 0.5863472 ,
#        0.89093785, 0.17650576, 0.46371669, 0.28210579, 0.84694492,
#        0.60310024, 0.52476221, 0.67085183, 0.91857468, 0.41021346,
#        0.49878397, 0.21260249, 0.84045243, 0.536124  , 0.80097858,
# ...

# %%
rand_int = np.random.randint(100, 200, 20).reshape(4, 5)
rand_int
# Out:
# array([[150, 110, 108, 196, 125],
#        [162, 183, 193, 191, 115],
#        [184, 121, 117, 115, 172],
#        [148, 154, 175, 172, 184]])
