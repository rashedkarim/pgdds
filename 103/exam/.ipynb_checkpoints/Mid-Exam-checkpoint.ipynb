# %% [markdown]
# # 1. Import Necessary Library

# %%
# Name: Md Rashed Karim
# Student ID: 905242031
import numpy as np

# %% [markdown]
# # 2. Numpy Array
# i) Create 2 numpy 1D array (arr1,arr2) and populate data using random library function

# %%
arr1 = np.random.randint(15,size=5)
arr1
# Out:
# array([ 4, 10,  1, 10,  3])

# %%
arr2 = np.random.randint(20, 50, size=5)
arr2
# Out:
# array([42, 49, 29, 24, 37])

# %% [markdown]
# ii) Find out all the unique values from both arrays and print the output in a sorted manner

# %%
np.sort(np.unique(arr1))
# Out:
# array([ 1,  3,  4, 10])

# %%
np.sort(np.unique(arr2))
# Out:
# array([24, 29, 37, 42, 49])

# %% [markdown]
# iii) Find out the summation of all even numbers of these arrays

# %%
even_arr1 = arr1[arr1 % 2 == 0].sum()
even_arr1
# Out:
# 24

# %%
even_arr2 = arr2[arr2 % 2 == 0].sum()
even_arr2
# Out:
# 66

# %% [markdown]
# iv) Create a 2D array combining this 2 array

# %%
d2 = np.vstack((arr1, arr2))
d2
# Out:
# array([[ 4, 10,  1, 10,  3],
#        [42, 49, 29, 24, 37]])

# %% [markdown]
# v) Find the maximum value of each column

# %%
column_max = np.max(d2, axis=0)
column_max
# Out:
# array([42, 49, 29, 24, 37])

# %% [markdown]
# # 3. Pandas
# i) import data from provided file and display

# %%
import pandas as pd
df = pd.read_csv("movie.csv")
df
# Out:
#                                            title    year  color  \
# 0                                         Avatar  2009.0  Color
# 1       Pirates of the Caribbean: At World's End  2007.0  Color
# 2                                        Spectre  2015.0  Color
# 3                          The Dark Knight Rises  2012.0  Color
# 4     Star Wars: Episode VII - The Force Awakens     NaN    NaN
# ...                                          ...     ...    ...
# 4911                     Signed Sealed Delivered  2013.0  Color
# 4912                               The Following     NaN  Color
# 4913                        A Plague So Pleasant  2013.0  Color
# 4914                            Shanghai Calling  2012.0  Color
# 4915                           My Date with Drew  2004.0  Color
#
#      content_rating  duration      director_name  director_fb  \
# 0             PG-13     178.0      James Cameron          0.0
# 1             PG-13     169.0     Gore Verbinski        563.0
# ...

# %% [markdown]
# ii) Do the necessary for missing value handling apply appropriate technique

# %%
print("Missing values in the DataFrame:")
df.isnull()
# Out:
# Missing values in the DataFrame:
#       title   year  color  content_rating  duration  director_name  \
# 0     False  False  False           False     False          False
# 1     False  False  False           False     False          False
# 2     False  False  False           False     False          False
# 3     False  False  False           False     False          False
# 4     False   True   True            True      True          False
# ...     ...    ...    ...             ...       ...            ...
# 4911  False  False  False            True     False          False
# 4912  False   True  False           False     False           True
# 4913  False  False  False            True     False          False
# 4914  False  False  False           False     False          False
# 4915  False  False  False           False     False          False
#
#       director_fb  actor1  actor1_fb  actor2  ...  actor3_fb  gross  genres  \
# ...

# %%
df.dropna()
# Out:
#                                          title    year  color content_rating  \
# 0                                       Avatar  2009.0  Color          PG-13
# 1     Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 2                                      Spectre  2015.0  Color          PG-13
# 3                        The Dark Knight Rises  2012.0  Color          PG-13
# 5                                  John Carter  2012.0  Color          PG-13
# ...                                        ...     ...    ...            ...
# 4906                                    Primer  2004.0  Color          PG-13
# 4907                                    Cavite  2005.0  Color      Not Rated
# 4908                               El Mariachi  1992.0  Color              R
# 4910                                 Newlyweds  2011.0  Color      Not Rated
# 4915                         My Date with Drew  2004.0  Color             PG
#
# ...

# %% [markdown]
# iii) Change inappropriate data type (if any)

# %%
df['year'] = df['year'] = df['year'].fillna(0).astype(int)
df
# Out:
#                                            title  year  color content_rating  \
# 0                                         Avatar  2009  Color          PG-13
# 1       Pirates of the Caribbean: At World's End  2007  Color          PG-13
# 2                                        Spectre  2015  Color          PG-13
# 3                          The Dark Knight Rises  2012  Color          PG-13
# 4     Star Wars: Episode VII - The Force Awakens     0    NaN            NaN
# ...                                          ...   ...    ...            ...
# 4911                     Signed Sealed Delivered  2013  Color            NaN
# 4912                               The Following     0  Color          TV-14
# 4913                        A Plague So Pleasant  2013  Color            NaN
# 4914                            Shanghai Calling  2012  Color          PG-13
# 4915                           My Date with Drew  2004  Color             PG
#
# ...

# %% [markdown]
# iv) Rename the column with meaningful name (at least one column)

# %%
df.rename(columns={'title': 'Movie Name'})
# Out:
#                                       Movie Name  year  color content_rating  \
# 0                                         Avatar  2009  Color          PG-13
# 1       Pirates of the Caribbean: At World's End  2007  Color          PG-13
# 2                                        Spectre  2015  Color          PG-13
# 3                          The Dark Knight Rises  2012  Color          PG-13
# 4     Star Wars: Episode VII - The Force Awakens     0    NaN            NaN
# ...                                          ...   ...    ...            ...
# 4911                     Signed Sealed Delivered  2013  Color            NaN
# 4912                               The Following     0  Color          TV-14
# 4913                        A Plague So Pleasant  2013  Color            NaN
# 4914                            Shanghai Calling  2012  Color          PG-13
# 4915                           My Date with Drew  2004  Color             PG
#
# ...

# %% [markdown]
# v) Select the highest budgeted movie

# %%
df[df['budget'] == df['budget'].max()]
# Out:
#                title  year  color content_rating  duration   director_name  \
# 3787  Lady Vengeance  2005  Color              R     112.0  Chan-wook Park
#
#       director_fb        actor1  actor1_fb        actor2  ...  actor3_fb  \
# 3787          0.0  Min-sik Choi      717.0  Yeong-ae Lee  ...       38.0
#
#          gross       genres  num_reviews num_voted_users  \
# 3787  211667.0  Crime|Drama        202.0           53508
#
#                                           plot_keywords  language  \
# 3787  cake|christian|lesbian sex|oral sex|pregnant s...    Korean
#
#           country        budget imdb_score
# 3787  South Korea  4.200000e+09        7.7
#
# [1 rows x 22 columns]

# %% [markdown]
# vi) Select the best 10 movies according their imdb score

# %%
df.head(10)
# Out:
#                                         title  year  color content_rating  \
# 0                                      Avatar  2009  Color          PG-13
# 1    Pirates of the Caribbean: At World's End  2007  Color          PG-13
# 2                                     Spectre  2015  Color          PG-13
# 3                       The Dark Knight Rises  2012  Color          PG-13
# 4  Star Wars: Episode VII - The Force Awakens     0    NaN            NaN
# 5                                 John Carter  2012  Color          PG-13
# 6                                Spider-Man 3  2007  Color          PG-13
# 7                                     Tangled  2010  Color             PG
# 8                     Avengers: Age of Ultron  2015  Color          PG-13
# 9      Harry Potter and the Half-Blood Prince  2009  Color             PG
#
#    duration      director_name  director_fb           actor1  actor1_fb  \
# 0     178.0      James Cameron          0.0      CCH Pounder     1000.0
# ...

# %% [markdown]
# vii) Select all the movies such that the Facebook likes for actor 2 are greater than those for
# actor 1

# %%
# df.info()
df[df['actor2_fb'] > df['actor1_fb']]
# Out:
# Empty DataFrame
# Columns: [title, year, color, content_rating, duration, director_name, director_fb, actor1, actor1_fb, actor2, actor2_fb, actor3, actor3_fb, gross, genres, num_reviews, num_voted_users, plot_keywords, language, country, budget, imdb_score]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# viii) Find out the director who produced the highest number of movies

# %%
director_movie_count = df.groupby('director_name')['title'].count()
director_movie_count
top_director = director_movie_count.idxmax()
max_movies = director_movie_count.max()

print(f'The director: "{top_director}" who produced {max_movies} movies.')
# df[df['director_name'] > df['actor1_fb']]
# Out:
# The director: "Steven Spielberg" who produced 26 movies.
