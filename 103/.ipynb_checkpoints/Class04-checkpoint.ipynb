# %%
import pandas as pd

# %%
df = pd.read_csv("DataSet/airbnb.csv")
df.head()
# Out:
#      id        neighborhood        room_type  accommodates  bedrooms  price  \
# 0  3686  Historic Anacostia     Private room             1       1.0     55
# 1  3943            Edgewood     Private room             2       1.0     71
# 2  4529    Eastland Gardens     Private room             4       1.0     54
# 3  4967            Edgewood     Private room             1       1.0     99
# 4  5589    Kalorama Heights  Entire home/apt             3       1.0     99
#
#    security_deposit  cleaning_fee  rating  superhost       response_time  \
# 0                25            25    4.60          0  a few days or more
# 1                50             0    4.81          0                 NaN
# 2                25            50    4.66          0  within a few hours
# 3                50             0    4.74          1      within an hour
# 4                50             0    4.54          0  within a few hours
#
# ...

# %%
df[(df["num_reviews"] > 0) & (df["rating"] >= 4)][["neighborhood", "price", "rating", "num_reviews"]].head(10)
# Out:
#          neighborhood  price  rating  num_reviews
# 0  Historic Anacostia     55    4.60           76
# 1            Edgewood     71    4.81          434
# 2    Eastland Gardens     54    4.66          102
# 3            Edgewood     99    4.74           31
# 4    Kalorama Heights     99    4.54           95
# 5       Spring Valley     68    4.80           91
# 6    Kalorama Heights     42    4.86          112
# 7       Dupont Circle    195    4.75          156
# 8   Cathedral Heights    125    4.59          403
# 9   Cathedral Heights     60    4.68          100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7805 entries, 0 to 7804
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7805 non-null   int64
#  1   neighborhood      7805 non-null   object
#  2   room_type         7805 non-null   object
#  3   accommodates      7805 non-null   int64
#  4   bedrooms          7021 non-null   float64
#  5   price             7805 non-null   int64
#  6   security_deposit  7805 non-null   int64
#  7   cleaning_fee      7805 non-null   int64
#  8   rating            5912 non-null   float64
#  9   superhost         7805 non-null   int64
#  10  response_time     5002 non-null   object
#  11  acceptance_rate   5407 non-null   object
#  12  host_since        7795 non-null   object
#  13  last_review       5912 non-null   object
#  14  num_reviews       7805 non-null   int64
#  15  latitude          7805 non-null   float64
# ...

# %%
df["room_type"].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# id                    int64
# neighborhood         object
# room_type            object
# accommodates          int64
# bedrooms            float64
# price                 int64
# security_deposit      int64
# cleaning_fee          int64
# rating              float64
# superhost             int64
# response_time        object
# acceptance_rate      object
# host_since           object
# last_review          object
# num_reviews           int64
# latitude            float64
# longitude           float64
# minimum_nights        int64
# maximum_nights        int64
# dtype: object

# %%
df.describe()
# Out:
#                  id  accommodates     bedrooms        price  security_deposit  \
# count  7.805000e+03   7805.000000  7021.000000   7805.00000        7805.00000
# mean   2.931262e+07      3.589366     1.537673    197.04984          49.21845
# std    1.517140e+07      2.241875     0.909845    506.58086          63.01897
# min    3.686000e+03      1.000000     1.000000      0.00000           0.00000
# 25%    1.654563e+07      2.000000     1.000000     80.00000           0.00000
# 50%    2.838734e+07      3.000000     1.000000    119.00000          50.00000
# 75%    4.384227e+07      4.000000     2.000000    190.00000          50.00000
# max    5.228166e+07     16.000000     9.000000  24999.00000         400.00000
#
#        cleaning_fee       rating    superhost  num_reviews     latitude  \
# count   7805.000000  5912.000000  7805.000000  7805.000000  7805.000000
# mean      41.370916     4.684770     0.259577    39.180013    38.911228
# ...
